# %% [markdown]
# ![alt text](perceptron_formula-1.svg)

# %% [markdown]
# ## 학습  - 오차를 줄이는 방향
#
# wi​←wi​+η⋅(y−y^​)⋅xi​

# %%
# 정답 1 예측 0 (과소)  오차  +1
# w_new = w_old + lr*(y-y_hat)*x
0.3+0.5*(1-0)*1  # 0.8
# w_old 0.3
# w_new 0.8
# delta_w  0.5

# 정답0 예측 1 (과대)  오차 -1
0.3+0.5*(0-1)*1  # -0.2
# w_old 0.3
# w의 변화량 -0.5

# 정답 1 예측 1
0.3+0.5*(1-1)*1  # 0.3
# w_old 0.3
# w의 변화량 0
# Out:
# 0.3
