# %% [markdown]
# $$
# \frac{f(x+h)-f(x)}{h}
# $$

# %% [markdown]
# $$
# \text{Gradient}=\frac{\partial L}{\partial W}
# $$

# %% [markdown]
# - 모델: $\hat{y}=Wx$ (bias 생략)
# - 손실(한 샘플): $L=(y-\hat{y})^2=(y-Wx)^2$
#
# 이제 $W$로 미분하면:
#
# $$
# \frac{dL}{dW}
# = 2(y-Wx)\cdot\frac{d(y-Wx)}{dW}
# = 2(y-Wx)\cdot(-x)
# = -2x(y-Wx)
# $$
#
# 이 값이 바로 **기울기**입니다.

# %% [markdown]
# $$
# W_{\text{new}} = W_{\text{old}} - \eta \frac{dL}{dW}
# $$

# %%
# y = wx
x , y = 2,4
w = 1
lr = 0.1

predict = w*x
L = (y - predict)**2
print(f'step1 w: {w}, loss: {L}')
gradient = -2*x*(y - predict)
w = w - lr*gradient
print(f'step1 new w: {w}, gradient: {gradient}')

predict = w*x
L = (y - predict)**2
print(f'step2 w: {w}, loss: {L}')
gradient = -2*x*(y - predict)
w = w - lr*gradient
print(f'step2 new w: {w}, gradient: {gradient}')

predict = w*x
L = (y - predict)**2
print(f'step3 w: {w}, loss: {L}')
gradient = -2*x*(y - predict)
w = w - lr*gradient
print(f'step3 new w: {w}, gradient: {gradient}')
# Out:
# step1 w: 1, loss: 4
# step1 new w: 1.8, gradient: -8
# step2 w: 1.8, loss: 0.15999999999999992
# step2 new w: 1.96, gradient: -1.5999999999999996
# step3 w: 1.96, loss: 0.006400000000000012
# step3 new w: 1.992, gradient: -0.3200000000000003

# %%
# y = wx
import numpy as np
x , y = 2,4
w = np.random.rand()
lr = 0.1
epochs = 100

for epoch in range(epochs):
    predict = w*x
    L = (y - predict)**2
    print(f'step{epoch + 1} w: {w}, loss: {L}')
    gradient = -2*x*(y - predict)
    w = w - lr*gradient
    print(f'step{epoch + 1} new w: {w}, gradient: {gradient}\n')
# Out:
# step1 w: 0.896010299906712, loss: 4.875173031648273
# step1 new w: 1.7792020599813425, gradient: -8.831917600746305
#
# step2 w: 1.7792020599813425, loss: 0.1950069212659307
# step2 new w: 1.9558404119962685, gradient: -1.76638352014926
#
# step3 w: 1.9558404119962685, loss: 0.007800276850637243
# step3 new w: 1.9911680823992537, gradient: -0.35327670402985234
#
# step4 w: 1.9911680823992537, loss: 0.00031201107402548974
# step4 new w: 1.9982336164798506, gradient: -0.07065534080597047
#
# step5 w: 1.9982336164798506, loss: 1.2480442961020844e-05
# step5 new w: 1.99964672329597, gradient: -0.014131068161194804
#
# step6 w: 1.99964672329597, loss: 4.992177184410848e-07
# step6 new w: 1.999929344659194, gradient: -0.0028262136322396714
#
# step7 w: 1.999929344659194, loss: 1.9968708737693595e-08
# step7 new w: 1.9999858689318388, gradient: -0.0005652427264486448
#
# step8 w: 1.9999858689318388, loss: 7.987483495027235e-10
# step8 new w: 1.9999971737863678, gradient: -0.00011304854528937369
#
# step9 w: 1.9999971737863678, loss: 3.1949933980108934e-11
# step9 new w: 1.9999994347572736, gradient: -2.260970905787474e-05
#
# step10 w: 1.9999994347572736, loss: 1.277997359003543e-12
# step10 new w: 1.9999998869514548, gradient: -4.521941811219676e-06
#
# step11 w: 1.9999998869514548, loss: 5.1119894279815893e-14
# step11 new w: 1.999999977390291, gradient: -9.043883615333925e-07
#
# step12 w: 1.999999977390291, loss: 2.0447957631600537e-15
# step12 new w: 1.9999999954780583, gradient: -1.8087767195140714e-07
#
# step13 w: 1.9999999954780583, loss: 8.179182731336928e-17
# step13 new w: 1.9999999990956117, gradient: -3.617553367973869e-08
#
# step14 w: 1.9999999990956117, loss: 3.271673092534771e-18
# step14 new w: 1.9999999998191222, gradient: -7.235106735947738e-09
#
# step15 w: 1.9999999998191222, loss: 1.3086705222273574e-19
# step15 new w: 1.9999999999638245, gradient: -1.4470220577322834e-09
#
# step16 w: 1.9999999999638245, loss: 5.234669236779673e-21
# step16 new w: 1.999999999992765, gradient: -2.894040562750888e-10
#
# step17 w: 1.999999999992765, loss: 2.0938676947118692e-22
# step17 new w: 1.999999999998553, gradient: -5.788081125501776e-11
#
# step18 w: 1.999999999998553, loss: 8.3759848716108e-24
# step18 new w: 1.9999999999997107, gradient: -1.1576517522371432e-11
#
# step19 w: 1.9999999999997107, loss: 3.348337861580952e-25
# step19 new w: 1.999999999999942, gradient: -2.3145929617385264e-12
#
# step20 w: 1.999999999999942, loss: 1.3434498431140136e-26
# step20 new w: 1.9999999999999885, gradient: -4.636291350834654e-13
#
# step21 w: 1.9999999999999885, loss: 5.33269971929404e-28
# step21 new w: 1.9999999999999978, gradient: -9.237055564881302e-14
#
# step22 w: 1.9999999999999978, loss: 1.9721522630525295e-29
# step22 new w: 1.9999999999999996, gradient: -1.7763568394002505e-14
#
# step23 w: 1.9999999999999996, loss: 7.888609052210118e-31
# step23 new w: 2.0, gradient: -3.552713678800501e-15
#
# step24 w: 2.0, loss: 0.0
# step24 new w: 2.0, gradient: -0.0
#
# step25 w: 2.0, loss: 0.0
# step25 new w: 2.0, gradient: -0.0
#
# step26 w: 2.0, loss: 0.0
# step26 new w: 2.0, gradient: -0.0
#
# step27 w: 2.0, loss: 0.0
# step27 new w: 2.0, gradient: -0.0
#
# step28 w: 2.0, loss: 0.0
# step28 new w: 2.0, gradient: -0.0
#
# step29 w: 2.0, loss: 0.0
# step29 new w: 2.0, gradient: -0.0
#
# step30 w: 2.0, loss: 0.0
# step30 new w: 2.0, gradient: -0.0
#
# step31 w: 2.0, loss: 0.0
# step31 new w: 2.0, gradient: -0.0
#
# step32 w: 2.0, loss: 0.0
# step32 new w: 2.0, gradient: -0.0
#
# step33 w: 2.0, loss: 0.0
# step33 new w: 2.0, gradient: -0.0
#
# step34 w: 2.0, loss: 0.0
# step34 new w: 2.0, gradient: -0.0
#
# step35 w: 2.0, loss: 0.0
# step35 new w: 2.0, gradient: -0.0
#
# step36 w: 2.0, loss: 0.0
# step36 new w: 2.0, gradient: -0.0
#
# step37 w: 2.0, loss: 0.0
# step37 new w: 2.0, gradient: -0.0
#
# step38 w: 2.0, loss: 0.0
# step38 new w: 2.0, gradient: -0.0
#
# step39 w: 2.0, loss: 0.0
# step39 new w: 2.0, gradient: -0.0
#
# step40 w: 2.0, loss: 0.0
# step40 new w: 2.0, gradient: -0.0
#
# step41 w: 2.0, loss: 0.0
# step41 new w: 2.0, gradient: -0.0
#
# step42 w: 2.0, loss: 0.0
# step42 new w: 2.0, gradient: -0.0
#
# step43 w: 2.0, loss: 0.0
# step43 new w: 2.0, gradient: -0.0
#
# step44 w: 2.0, loss: 0.0
# step44 new w: 2.0, gradient: -0.0
#
# step45 w: 2.0, loss: 0.0
# step45 new w: 2.0, gradient: -0.0
#
# step46 w: 2.0, loss: 0.0
# step46 new w: 2.0, gradient: -0.0
#
# step47 w: 2.0, loss: 0.0
# step47 new w: 2.0, gradient: -0.0
#
# step48 w: 2.0, loss: 0.0
# step48 new w: 2.0, gradient: -0.0
#
# step49 w: 2.0, loss: 0.0
# step49 new w: 2.0, gradient: -0.0
#
# step50 w: 2.0, loss: 0.0
# step50 new w: 2.0, gradient: -0.0
#
# step51 w: 2.0, loss: 0.0
# step51 new w: 2.0, gradient: -0.0
#
# step52 w: 2.0, loss: 0.0
# step52 new w: 2.0, gradient: -0.0
#
# step53 w: 2.0, loss: 0.0
# step53 new w: 2.0, gradient: -0.0
#
# step54 w: 2.0, loss: 0.0
# step54 new w: 2.0, gradient: -0.0
#
# step55 w: 2.0, loss: 0.0
# step55 new w: 2.0, gradient: -0.0
#
# step56 w: 2.0, loss: 0.0
# step56 new w: 2.0, gradient: -0.0
#
# step57 w: 2.0, loss: 0.0
# step57 new w: 2.0, gradient: -0.0
#
# step58 w: 2.0, loss: 0.0
# step58 new w: 2.0, gradient: -0.0
#
# step59 w: 2.0, loss: 0.0
# step59 new w: 2.0, gradient: -0.0
#
# step60 w: 2.0, loss: 0.0
# step60 new w: 2.0, gradient: -0.0
#
# step61 w: 2.0, loss: 0.0
# step61 new w: 2.0, gradient: -0.0
#
# step62 w: 2.0, loss: 0.0
# step62 new w: 2.0, gradient: -0.0
#
# step63 w: 2.0, loss: 0.0
# step63 new w: 2.0, gradient: -0.0
#
# step64 w: 2.0, loss: 0.0
# step64 new w: 2.0, gradient: -0.0
#
# step65 w: 2.0, loss: 0.0
# step65 new w: 2.0, gradient: -0.0
#
# step66 w: 2.0, loss: 0.0
# step66 new w: 2.0, gradient: -0.0
#
# step67 w: 2.0, loss: 0.0
# step67 new w: 2.0, gradient: -0.0
#
# step68 w: 2.0, loss: 0.0
# step68 new w: 2.0, gradient: -0.0
#
# step69 w: 2.0, loss: 0.0
# step69 new w: 2.0, gradient: -0.0
#
# step70 w: 2.0, loss: 0.0
# step70 new w: 2.0, gradient: -0.0
#
# step71 w: 2.0, loss: 0.0
# step71 new w: 2.0, gradient: -0.0
#
# step72 w: 2.0, loss: 0.0
# step72 new w: 2.0, gradient: -0.0
#
# step73 w: 2.0, loss: 0.0
# step73 new w: 2.0, gradient: -0.0
#
# step74 w: 2.0, loss: 0.0
# step74 new w: 2.0, gradient: -0.0
#
# step75 w: 2.0, loss: 0.0
# step75 new w: 2.0, gradient: -0.0
#
# step76 w: 2.0, loss: 0.0
# step76 new w: 2.0, gradient: -0.0
#
# step77 w: 2.0, loss: 0.0
# step77 new w: 2.0, gradient: -0.0
#
# step78 w: 2.0, loss: 0.0
# step78 new w: 2.0, gradient: -0.0
#
# step79 w: 2.0, loss: 0.0
# step79 new w: 2.0, gradient: -0.0
#
# step80 w: 2.0, loss: 0.0
# step80 new w: 2.0, gradient: -0.0
#
# step81 w: 2.0, loss: 0.0
# step81 new w: 2.0, gradient: -0.0
#
# step82 w: 2.0, loss: 0.0
# step82 new w: 2.0, gradient: -0.0
#
# step83 w: 2.0, loss: 0.0
# step83 new w: 2.0, gradient: -0.0
#
# step84 w: 2.0, loss: 0.0
# step84 new w: 2.0, gradient: -0.0
#
# step85 w: 2.0, loss: 0.0
# step85 new w: 2.0, gradient: -0.0
#
# step86 w: 2.0, loss: 0.0
# step86 new w: 2.0, gradient: -0.0
#
# step87 w: 2.0, loss: 0.0
# step87 new w: 2.0, gradient: -0.0
#
# step88 w: 2.0, loss: 0.0
# step88 new w: 2.0, gradient: -0.0
#
# step89 w: 2.0, loss: 0.0
# step89 new w: 2.0, gradient: -0.0
#
# step90 w: 2.0, loss: 0.0
# step90 new w: 2.0, gradient: -0.0
#
# step91 w: 2.0, loss: 0.0
# step91 new w: 2.0, gradient: -0.0
#
# step92 w: 2.0, loss: 0.0
# step92 new w: 2.0, gradient: -0.0
#
# step93 w: 2.0, loss: 0.0
# step93 new w: 2.0, gradient: -0.0
#
# step94 w: 2.0, loss: 0.0
# step94 new w: 2.0, gradient: -0.0
#
# step95 w: 2.0, loss: 0.0
# step95 new w: 2.0, gradient: -0.0
#
# step96 w: 2.0, loss: 0.0
# step96 new w: 2.0, gradient: -0.0
#
# step97 w: 2.0, loss: 0.0
# step97 new w: 2.0, gradient: -0.0
#
# step98 w: 2.0, loss: 0.0
# step98 new w: 2.0, gradient: -0.0
#
# step99 w: 2.0, loss: 0.0
# step99 new w: 2.0, gradient: -0.0
#
# step100 w: 2.0, loss: 0.0
# step100 new w: 2.0, gradient: -0.0

# %%
# 사과 사격 : 100원
# 사과 개수 : 2개
# 소비세 : 1.1
# z = (100 x 2)x 1.1 

# 순전파(앞으로 계산)
# a = 100 x 2 = 200
# z = a x 1.1 = 220

# 최종금액이 1원 변할때 사과가격은 얼마나 변할까?

# %% [markdown]
# $\frac{\partial z}{\partial 100}$
# - 체인룰
# $$
# \frac{\partial z}{\partial 100}
# =
# \frac{\partial z}{\partial a}
# \cdot
# \frac{\partial a}{\partial 100}
# $$
# - 계산
# - $\frac{\partial z}{\partial a}=1.1$  (세금 곱하기)
# - $\frac{\partial a}{\partial 100}=2$  (개수 2개 곱하기)
#
# 따라서
#
# $$
# \frac{\partial z}{\partial 100}=1.1\times2=2.2
# $$

# %%
# 출력까지 여러연산으로 이루어져 있음
# 각 구간의 로컬변화율(미분)을 곱해서
# 최종적으로 DL / DW 구함

# 체인룰 : 출력오차가 앞단 가중치까지 어떻게 전파되는지 계산하는 규칙
# 이 값으로 w - lr*gradient 업데이트 수행

# 신경망(은닉층1, 출력층 1) --> 체이닝룰  
# 입력 x
# 은닉층 z1 = w1x + b1  , h = relu(z1)
# 출력층 z2 = w2h + b2,  yhat = sigmoid(z2)
# 손실 L  1/2(y - yhat)**2

# %% [markdown]
# - 출력층 미분
#
# $$
# \frac{\partial L}{\partial w_2}
# =
# \frac{\partial L}{\partial \hat{y}}
# \cdot
# \frac{\partial \hat{y}}{\partial z_2}
# \cdot
# \frac{\partial z_2}{\partial w_2}
# $$
#
# - $\frac{\partial L}{\partial \hat{y}}=\hat{y}-y$
# - $\frac{\partial \hat{y}}{\partial z_2}=\hat{y}(1-\hat{y})$ (시그모이드 미분)
# - $\frac{\partial z_2}{\partial w_2}=h$
#
# 따라서
# $$
# \frac{\partial L}{\partial w_2}
# =
# (\hat{y}-y)\hat{y}(1-\hat{y})h
# $$
#
#
# - 은닉층 가중치 미분
#
# $$
# \frac{\partial L}{\partial w_1}
# =
# \frac{\partial L}{\partial \hat{y}}
# \cdot
# \frac{\partial \hat{y}}{\partial z_2}
# \cdot
# \frac{\partial z_2}{\partial h}
# \cdot
# \frac{\partial h}{\partial z_1}
# \cdot
# \frac{\partial z_1}{\partial w_1}
# $$
#
# 각 항:
#
# - $\frac{\partial z_2}{\partial h}=w_2$
# - $\frac{\partial h}{\partial z_1}=h(1-h)$
# - $\frac{\partial z_1}{\partial w_1}=x$
#
# 따라서
# $$
# \frac{\partial L}{\partial w_1}
# =
# (\hat{y}-y)\hat{y}(1-\hat{y})w_2h(1-h)x
# $$
#
#
# 가중치 업데이트는 둘 다 동일합니다:
# $$
# w \leftarrow w-\eta\frac{\partial L}{\partial w}
# $$

# %%
# %conda install matplotlib

# %%
import torch
import matplotlib.pyplot as plt
torch.manual_seed(42)

# %%
# 기울기
# f(x) = x^2  f'(x) = 2x

h_value = [1.0,0.5,0.1,0.01,0.001]

x0 = 3.0
f_prime = 2*x0

for h in h_value:
    gradient = ((x0+h)**2 - x0**2) / h
    print(f'두점의 기울기 : {gradient}')

print(f'이론상 접선 기울기 : {x*x0}')
# Out:
# 두점의 기울기 : 7.0
# 두점의 기울기 : 6.5
# 두점의 기울기 : 6.100000000000012
# 두점의 기울기 : 6.009999999999849
# 두점의 기울기 : 6.000999999999479
# 이론상 접선 기울기 : 6.0

# %%
# 과일예제를 체인룰 코드 증명
# z = (사과가격 x 개수) x 세율

# DZ / D사과가격 = 개수 x 세율

import torch
apple_price = torch.tensor(100.0, requires_grad=True)
apple_count = 2.0
tax = 1.1

subtotal = apple_price * apple_count
total_price = subtotal * tax

total_price.backward() 

manual_gradient = apple_count * tax
auto_gradient = apple_price.grad.item()

print(manual_gradient, auto_gradient)
# Out:
# 2.2 2.200000047683716

# %%
# f(x)  = wx
