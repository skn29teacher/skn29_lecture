# %%
class TestTemp:
    def funA(self):
        print('FunA')
        return self
    def funB(self):
        print('FunB')
        return self
    def funC(self):
        print('FunC')
        return self

TestTemp().funA().funB().funC()
# Out:
# FunA
# FunB
# FunC
