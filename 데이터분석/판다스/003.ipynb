# %%
import pandas as pd
filepath = '20220207.csv'
df = pd.read_csv(filepath,encoding='cp949')
df.head()

# 결측치여부 확인 만약 있다면 결측치가 있는 데이터만 출력
df.isna().any()
# 결측치를 채운다  평균또는 중위수  문자열  빈도수가 많은 문자열로대처
# 단속원금이 가장 큰 순으로 정렬해서 top 5 출력
df.rename(columns={'단속원금(원)':'단속원금'},inplace=True)
dt_5 = df.sort_values(by=['단속원금'],ascending=False).iloc[:5]
dt_5
# 연도 언제부터 언제까지인지
df['연도'].min(), df['연도'].max()
# Out:
# (2017, 2021)
