# %%
import pandas as pd
df = pd.read_csv('20220207.csv',encoding='cp949',header=0)
df_2017 = df[df['연도'] == 2017]
df_2017.to_csv('2017.csv',encoding='utf-8')

# %%
df_2017.to_excel('2017_excel.xlsx')

# %%
df_2017.to_json('2017_json.json',force_ascii=False,orient='records', indent=4)

# %%
# %pip install sqlalchemy

# %%
# %pip install pymysql

# %%
from sqlalchemy import create_engine, text
import os
from dotenv import load_dotenv
load_dotenv()

user_id = os.getenv('DB_USER')
user_pwd = os.getenv('DB_PASSWORD')
db_name = os.getenv('DB_NAME')

engine = create_engine(f'mysql+pymysql://{user_id}:{user_pwd}@localhost:3306/{db_name}')
conn = engine.connect()
result = conn.execute(text("select 1"))
print(result.fetchall())
conn.close()
# Out:
# [(1,)]

# %%
engine = create_engine(f'mysql+pymysql://{user_id}:{user_pwd}@localhost:3306/{db_name}')
pd.read_sql('select * from sale_car',engine)
# Out:
#     sale_car_id  year  month company  amount
# 0             1  2025      1      기아   38412
# 1             2  2025      1      현대   37230
# 2             3  2025      1    제네시스    8824
# 3             4  2025      1   르노코리아    2601
# 4             5  2025      1     KGM    2300
# ..          ...   ...    ...     ...     ...
# 67           68  2025     12      기아   44831
# 68           69  2025     12    제네시스    9680
# 69           70  2025     12   르노코리아    4771
# 70           71  2025     12     KGM    2659
# 71           72  2025     12     쉐보레    1126
#
# [72 rows x 5 columns]
