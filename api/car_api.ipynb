# %% [markdown]
# 공공데이터 포털
#
# https://www.data.go.kr/data/15059401/openapi.do

# %%
# U5i63xpIWM48raIRQBYpUXbA%2FwKd0iO6n%2Fn1%2BJISyoEW1gWcEiz2No2fHPeid5TZoQN0HV85WyGv6LPwaQ8n4w%3D%3D

import requests
import xml.etree.ElementTree as ET

service_key = 'U5i63xpIWM48raIRQBYpUXbA/wKd0iO6n/n1+JISyoEW1gWcEiz2No2fHPeid5TZoQN0HV85WyGv6LPwaQ8n4w=='
url = 'https://apis.data.go.kr/B553881/newRegistlnfoService_02/getnewRegistlnfoService02'

params = {
    'serviceKey' : service_key,
    'registYy' : '2026',
    'registMt' : '02',
    'vhctyAsortCode' :1,
    'registGrcCode'   : 1
}
response = requests.get(url,params=params)
print(f'코드 : {response.status_code}')
print(response.text) # 문자열 xml 구조

root = ET.fromstring(response.text)

for child in root.find('header'):  # Element 객체
    print(child.tag, child.text)

for child in root.find('body'): # Element 객체
    print(child.tag, child.text)
# Out:
# 코드 : 200
# <response><header><resultCode>00</resultCode><resultMsg>NORMAL_CODE</resultMsg></header><body><dtaCo>9872</dtaCo></body></response>
# resultCode 00
# resultMsg NORMAL_CODE
# dtaCo 9872

# %%
# %pip install xmltodict
# Out:
# ...
# Note: you may need to restart the kernel to use updated packages.

# %%
import xmltodict
data = xmltodict.parse(response.text)

print(data)
# Out:
# {'response': {'header': {'resultCode': '00', 'resultMsg': 'NORMAL_CODE'}, 'body': {'dtaCo': '9872'}}}
